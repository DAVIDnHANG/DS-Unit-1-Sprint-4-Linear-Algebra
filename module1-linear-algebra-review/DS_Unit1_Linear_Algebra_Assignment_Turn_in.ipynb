# %% [markdown]
# <a href="https://colab.research.google.com/github/DAVIDnHANG/DS-Unit-1-Sprint-4-Linear-Algebra/blob/master/module1-linear-algebra-review/DS_Unit1_Linear_Algebra_Assignment_Turn_in.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.1 Create a two-dimensional vector and plot it on a graph

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(5,5))
plt.arrow(0,0,3,3, head_width=.4, head_length=.5)

plt.grid(b=None, which='both')
plt.xlim(-5,5)
plt.ylim(-5,5)
plt.show()

# %% [markdown]
# 1.2 Create a three-dimensional vecor and plot it on a graph

# %%
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt
#set the fig,ax
fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
#plot line

ax.quiver([2,3],3,3, 4, -4, -5)

#set the x,y,z limit, and show
ax.set_xlim(-5,5)
ax.set_ylim(0,5)
ax.set_zlim(-5,5)
plt.show()

# %%
#come back later for 2)
import matplotlib
matplotlib.use('QT4Agg')
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d

class MyAxes3D(axes3d.Axes3D):

    def __init__(self, baseObject, sides_to_draw):
        self.__class__ = type(baseObject.__class__.__name__,
                              (self.__class__, baseObject.__class__),
                              {})
        self.__dict__ = baseObject.__dict__
        self.sides_to_draw = list(sides_to_draw)
        self.mouse_init()

    def set_some_features_visibility(self, visible):
        for t in self.w_zaxis.get_ticklines() + self.w_zaxis.get_ticklabels():
            t.set_visible(visible)
        self.w_zaxis.line.set_visible(visible)
        self.w_zaxis.pane.set_visible(visible)
        self.w_zaxis.label.set_visible(visible)

    def draw(self, renderer):
        # set visibility of some features False 
        self.set_some_features_visibility(False)
        # draw the axes
        super(MyAxes3D, self).draw(renderer)
        # set visibility of some features True. 
        # This could be adapted to set your features to desired visibility, 
        # e.g. storing the previous values and restoring the values
        self.set_some_features_visibility(True)

        zaxis = self.zaxis
        draw_grid_old = zaxis.axes._draw_grid
        # disable draw grid
        zaxis.axes._draw_grid = False

        tmp_planes = zaxis._PLANES

        if 'l' in self.sides_to_draw :
            # draw zaxis on the left side
            zaxis._PLANES = (tmp_planes[2], tmp_planes[3],
                             tmp_planes[0], tmp_planes[1],
                             tmp_planes[4], tmp_planes[5])
            zaxis.draw(renderer)
        if 'r' in self.sides_to_draw :
            # draw zaxis on the right side
            zaxis._PLANES = (tmp_planes[3], tmp_planes[2], 
                             tmp_planes[1], tmp_planes[0], 
                             tmp_planes[4], tmp_planes[5])
            zaxis.draw(renderer)

        zaxis._PLANES = tmp_planes

        # disable draw grid
        zaxis.axes._draw_grid = draw_grid_old

def example_surface(ax):
    """ draw an example surface. code borrowed from http://matplotlib.org/examples/mplot3d/surface3d_demo.html """
    from matplotlib import cm
    import numpy as np
    X = np.arange(-5, 5, 0.25)
    Y = np.arange(-5, 5, 0.25)
    X, Y = np.meshgrid(X, Y)
    R = np.sqrt(X**2 + Y**2)
    Z = np.sin(R)
    surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.coolwarm, linewidth=0, antialiased=False)

if __name__ == '__main__':
    fig = plt.figure(figsize=(15, 5))
    ax = fig.add_subplot(131, projection='3d')
    ax.set_title('z-axis left side')
    ax = fig.add_axes(MyAxes3D(ax, 'l'))
    example_surface(ax) # draw an example surface
    ax = fig.add_subplot(132, projection='3d')
    ax.set_title('z-axis both sides')
    ax = fig.add_axes(MyAxes3D(ax, 'lr'))
    example_surface(ax) # draw an example surface
    ax = fig.add_subplot(133, projection='3d')
    ax.set_title('z-axis right side')
    ax = fig.add_axes(MyAxes3D(ax, 'r'))
    example_surface(ax) # draw an example surface
    plt.show()

# %% [markdown]
# 1.3 Scale the vectors you created in 1.1 by $5$, $\pi$, and $-e$ and plot all four vectors (original + 3 scaled vectors) on a graph. What do you notice about these vectors

# %%
import matplotlib.pyplot as plt
from math import e, pi
plt.figure(figsize=(5,5))
plt.arrow(0,0,e* 3, e * 3, head_width=.4, head_length=.5, color='purple')

plt.grid(b=None, which='both')
plt.xlim(0,15)
plt.ylim(0,15)
plt.show()

plt.arrow(0,0,pi * 3, pi * 3, head_width=.4, head_length=.5, color='blue')
plt.grid(b=None, which='both')
plt.xlim(0,15)
plt.ylim(0,15)
plt.show()

#graph becomes bigger by [e*3(i), e*3], and pi respectally.

# %% [markdown]
# graph becomes bigger by $e3i$ and $e3j $, and $\pi$ $3i$ and $\pi$$3j$ respectally.

# %% [markdown]
# 1.4 Graph vectors $\vec{a}$ and $\vec{b}$ and plot them on a graph

# %%
import matplotlib.pyplot as plt
from math import e, pi
plt.figure(figsize=(5,5))
plt.arrow(0,0,5,7, head_width=.3, head_length=.5, color='purple')
plt.arrow(0,0,3,4, head_width=.1, head_length=.5, color='blue')
plt.grid(b=None, which='both')
plt.xlim(0,8)
plt.ylim(0,8)
plt.show()

# %% [markdown]
# 1.5 find $\vec{a} - \vec{b}$ and plot the result on the same graph as $\vec{a}$ and $\vec{b}$. Is there a relationship between vectors $\vec{a} \thinspace, \vec{b} \thinspace \text{and} \thinspace \vec{a-b}$
#
#
#
#
# 1.   the a-b vector  lenght is the start from the tip of vector a and ends at the tip of vector b,
# 2.   in other words, you can start a-b vector from the end of vector a, and it will end at the end of vector b.

# %%
import matplotlib.pyplot as plt
from math import e, pi
plt.figure(figsize=(5,5))
plt.arrow(0,0,5,7, head_width=.1, head_length=.2, color='purple')
plt.arrow(0,0,3,4, head_width=.1, head_length=.3, color='blue')
plt.arrow(3,4,5-3,7-4, head_width=.1, head_length=.2, color='grey')
plt.grid(b=None, which='both')
plt.xlim(0,8)
plt.ylim(0,8)
plt.show()

# %% [markdown]
# .6 Find $c \cdot d$
# ```
# $c \cdot d$ = 7*12 + 22*6 + 4*2 + 16*9 =

# %%
import numpy as np
import numpy.linalg as linalg
c= [7,22,4,16]
d=[12,6,2,9]
np_c = np.asarray([7,22,4,16])
np_d = np.asarray(d)
#got to broadcast the array, times it by element wise first then use np.sum()
d = np_c*np_d
np.sum(d)
# Out:
# 368

# %% [markdown]
# 1.9) E x f

# %%
e = [5,7,2]
f = [3,4,6]
ed = np.asarray([e,f])
ed
# Out:
# array([[5, 7, 2],
#        [3, 4, 6]])

# %%
np.cross(e,f)
# Out:
# array([ 34, -24,  -1])

# %%
1.8 Find $||g||$ and then find $||h||$. Which is longer?

# %%
import numpy.linalg as linalg
g = [1,1,1,8] 
h = [3,3,3,3]
print(linalg.norm(g))
print(linalg.norm(h))
if (linalg.norm(g) < linalg.norm(h)):
  print("h is bigger")
else:
  print("g is bigger")
# Out:
# 8.18535277187245
# 6.0
# g is bigger

# %% [markdown]
# 2.1 What are the dimensions of the following matrices? Which of the following can be multiplied together? See if you can find all of the different legal combinations
#
# 1.   A is (2,3)
#
# 1.   B = (1,3)
# 2.   c = (3,2)
# 3.   D is (3,3)
# 4.   E is (2,2)
# 5.   AC= (3,3), AE = (3,2),
# 6.   CA = (2,2), CD=(2,3),
# 7.   DA=(3,3), DB=(3,1)
# 8.   EC = (2,3)

# %% [markdown]
# 2.2 Find the following products: CD, AE, and BA. What are the dimensions of the resulting matrices? How does that relate to the dimensions of their factor matrices?

# %%
import numpy.linalg as linalg
#cd will be
C =np.asarray([[9,6,3],[4,7,11]])
CT = C.T
D = np.asarray([[1,0,0],[0,1,0],[0,0,1]])
np.matmul(C,D)
print(np.matmul(C,D))
# CD is not defined because we can't multiply a matrix with size 2x3 by 3x3

A =np.asarray([[1,2],[3,4],[5,6]])
E = np.asarray([[1,3],[5,7]])
print(np.matmul(A,E))
#can;t not multiply matrix AE. A 

#BA
B = np.asarray([[2,4,9]])
print(np.matmul(B,A))

#CD 
print(np.matmul(C,D))

#AE
print("AE",np.matmul(A,E))

#BA 
print("BA",np.matmul(B,A))
# Out:
# [[ 9  6  3]
#  [ 4  7 11]]
# [[11 17]
#  [23 37]
#  [35 57]]
# [[59 74]]
# [[ 9  6  3]
#  [ 4  7 11]]
# AE [[11 17]
#  [23 37]
#  [35 57]]
# BA [[59 74]]

# %%
# Out:
# array([[ 9,  6,  3],
#        [ 4,  7, 11]])

# %% [markdown]
# matrix along the diagonal of F is 20,15,10,5.
#
#
# 1.   dim $F^T$ is 4x5
# 2.   Dim F is 5x4

# %% [markdown]
# FIND IG

# %%
G = np.asarray([[12,11],[7,10]])
a = np.identity(2)
print('a is\n', a)
IG = np.matmul(a,G)
print('IG is \n' , IG)
# Out:
# a is
#  [[1. 0.]
#  [0. 1.]]
# IG is
#  [[12. 11.]
#  [ 7. 10.]]

# %% [markdown]
# Find $|H|$ and then find $|J|$.

# %%
H = np.asarray([[12,11], [7,10]])
J = np.asarray([[0,1,2],[7,10,4], [3,2,0]])
print('det of H',linalg.det(H))
print('det of J',linalg.det(J))
# Out:
# det of H 43.000000000000014
# det of J -19.999999999999996

# %%
invH = linalg.inv(H)
invJ = linalg.inv(J)
print('inv of H \n',linalg.inv(H))
print('inv of J\n',linalg.inv(J))
# Out:
# inv of H
#  [[ 0.23255814 -0.25581395]
#  [-0.1627907   0.27906977]]
# inv of J
#  [[ 0.4  -0.2   0.8 ]
#  [-0.6   0.3  -0.7 ]
#  [ 0.8  -0.15  0.35]]

# %%
print(np.matmul(H,invH))
print(np.matmul(J,invJ))
# Out:
# [[1.00000000e+00 5.55111512e-16]
#  [2.22044605e-16 1.00000000e+00]]
# [[ 1.00000000e+00 -5.55111512e-17  0.00000000e+00]
#  [ 0.00000000e+00  1.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  1.00000000e+00]]

# %% [markdown]
# $HH^{-1} \neq JJ^{-1}$ because $HH^{-1}$ is 2x2, and $JJ^{-1}$ is 3x3
